# %%
load phase_plane.py

# %%
# import necessary libraries 
import matplotlib.pyplot as plt

# show the plots in the notebook
#% matplotlib inline

# define system in terms of separated differential equations

def f(x,y):
    return 5*x - 3*y -2
def g(x,y):
    return 4*x -3*y -1

# initialize lists contianing values
x = []
y = []

# iv1, iv2 = initial values, dt = timestep, time = range
def sys(iv1, iv2, dt, time):
    # initial values:
    x.append(iv1)
    y.append(iv2)

    # compute and fill lists
    # using eulers method
    for i in range(time):
        x.append(x[i]  + (f(x[i],y[i])) * dt)
        y.append(y[i]  + (g(x[i],y[i])) * dt)
    return x, y

sys(10,2,0.01,1000)

# plot 
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(x, 'r-', label='predator')
ax1.plot(y, 'b-', label='prey')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("Dynamics in time")
ax1.set_xlabel("time")
ax1.grid()
ax1.legend(loc='best')

ax2.plot(x, y, color="blue")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_title("Phase space")
ax2.grid()

# %%
# import necessary libraries 
import matplotlib.pyplot as plt

# %%
# %load phase_plane.py

# %%
# import necessary libraries 
import matplotlib.pyplot as plt

# show the plots in the notebook
#% matplotlib inline

# define system in terms of separated differential equations

def f(x,y):
    return 5*x - 3*y -2
def g(x,y):
    return 4*x -3*y -1

# initialize lists contianing values
x = []
y = []

# iv1, iv2 = initial values, dt = timestep, time = range
def sys(iv1, iv2, dt, time):
    # initial values:
    x.append(iv1)
    y.append(iv2)

    # compute and fill lists
    # using eulers method
    for i in range(time):
        x.append(x[i]  + (f(x[i],y[i])) * dt)
        y.append(y[i]  + (g(x[i],y[i])) * dt)
    return x, y

sys(10,2,0.01,1000)

# plot 
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(x, 'r-', label='predator')
ax1.plot(y, 'b-', label='prey')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("Dynamics in time")
ax1.set_xlabel("time")
ax1.grid()
ax1.legend(loc='best')

ax2.plot(x, y, color="blue")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_title("Phase space")
ax2.grid()

# %%
# %load phase_plane.py

# %%
# import necessary libraries 
import matplotlib.pyplot as plt

# show the plots in the notebook
# %matplotlib inline

# define system in terms of separated differential equations

def f(x,y):
    return 5*x - 3*y -2
def g(x,y):
    return 4*x -3*y -1

# initialize lists contianing values
x = []
y = []

# iv1, iv2 = initial values, dt = timestep, time = range
def sys(iv1, iv2, dt, time):
    # initial values:
    x.append(iv1)
    y.append(iv2)

    # compute and fill lists
    # using eulers method
    for i in range(time):
        x.append(x[i]  + (f(x[i],y[i])) * dt)
        y.append(y[i]  + (g(x[i],y[i])) * dt)
    return x, y

sys(10,2,0.01,1000)

# plot 
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(x, 'r-', label='predator')
ax1.plot(y, 'b-', label='prey')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("Dynamics in time")
ax1.set_xlabel("time")
ax1.grid()
ax1.legend(loc='best')

ax2.plot(x, y, color="blue")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_title("Phase space")
ax2.grid()

# %%
# import necessary libraries 
import matplotlib.pyplot as plt

# show the plots in the notebook
# %matplotlib inline

# define system in terms of separated differential equations

def f(x,y):
    return 5*x - 3*y -2
def g(x,y):
    return 4*x -3*y -1

# initialize lists contianing values
x = []
y = []

# iv1, iv2 = initial values, dt = timestep, time = range
def sys(iv1, iv2, dt, time):
    # initial values:
    x.append(iv1)
    y.append(iv2)

    # compute and fill lists
    # using eulers method
    for i in range(time):
        x.append(x[i]  + (f(x[i],y[i])) * dt)
        y.append(y[i]  + (g(x[i],y[i])) * dt)
    return x, y

sys(10,2,0.01,1000)

# plot 
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(x, 'r-', label='predator')
ax1.plot(y, 'b-', label='prey')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("Dynamics in time")
ax1.set_xlabel("time")
ax1.grid()
ax1.legend(loc='best')

ax2.plot(x, y, color="blue")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_title("Phase space")
ax2.grid()

# %%
# import necessary libraries 
import matplotlib.pyplot as plt
import numpy as np

# show the plots in the notebook
# %matplotlib inline

# define system in terms of separated differential equations

def f(x,y):
    return 5*x - 3*y -2
def g(x,y):
    return 4*x -3*y -1

# initialize lists contianing values
x = []
y = []

# iv1, iv2 = initial values, dt = timestep, time = range
def sys(iv1, iv2, dt, time):
    # initial values:
    x.append(iv1)
    y.append(iv2)

    # compute and fill lists
    # using eulers method
    for i in range(time):
        x.append(x[i]  + (f(x[i],y[i])) * dt)
        y.append(y[i]  + (g(x[i],y[i])) * dt)
    return x, y

sys(0,10,0.01,1000)

# plot 
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(x, 'r-', label='predator')
ax1.plot(y, 'b-', label='prey')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("Dynamics in time")
ax1.set_xlabel("time")
ax1.grid()
ax1.legend(loc='best')

ax2.plot(x, y, color="blue")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_title("Phase space")
ax2.grid()

# %%
#plot
fig2 = plt.figure(figsize=(8,6))
ax4 = fig2.add_subplot(1,1,1)

x = np.linspace(0,2,20)
y = np.arange(0,2,20)

# plot nullclines
ax4.plot([0,2],[2,0], 'r-', lw=2, label='x-nullcline')
ax4.plot([1,1],[0,2], 'b-', lw=2, label='y-nullcline')

# plot fixed points
for point in fp:
    ax4.plot(point[0],point[1],"red", marker = "o", markersize = 10.0)
ax4.set_title("Quiverplot with nullclines")
ax4.legend(loc='best')

# quiverplot
# define a grid and compute direction at each point
x = np.linspace(0, 2, 20)
y = np.linspace(0, 2, 20)

X1 , Y1  = np.meshgrid(x, y)                    # create a grid
DX1, DY1 = Sys([X1, Y1])                        # compute growth rate on the grid
M = (np.hypot(DX1, DY1))                        # norm growth rate 
M[ M == 0] = 1.                                 # avoid zero division errors 
DX1 /= M                                        # normalize each arrows
DY1 /= M

ax4.quiver(X1, Y1, DX1, DY1, M, pivot='mid')
ax4.legend()
ax4.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8cb75c091cee> in <module>()
#      11
#      12 # plot fixed points
# ---> 13 for point in fp:
#      14     ax4.plot(point[0],point[1],"red", marker = "o", markersize = 10.0)
#      15 ax4.set_title("Quiverplot with nullclines")
#
# NameError: name 'fp' is not defined
